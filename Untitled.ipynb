# %%
conda env create -f environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
#
# CondaValueError: prefix already exists: /Users/akshadapradhan/Documents/anaconda3/envs/cossmo
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate cossmo
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init bash
# Out:
# no change     /Users/akshadapradhan/Documents/anaconda3/condabin/conda
# no change     /Users/akshadapradhan/Documents/anaconda3/bin/conda
# no change     /Users/akshadapradhan/Documents/anaconda3/bin/conda-env
# no change     /Users/akshadapradhan/Documents/anaconda3/bin/activate
# no change     /Users/akshadapradhan/Documents/anaconda3/bin/deactivate
# no change     /Users/akshadapradhan/Documents/anaconda3/etc/profile.d/conda.sh
# no change     /Users/akshadapradhan/Documents/anaconda3/etc/fish/conf.d/conda.fish
# no change     /Users/akshadapradhan/Documents/anaconda3/shell/condabin/Conda.psm1
# no change     /Users/akshadapradhan/Documents/anaconda3/shell/condabin/conda-hook.ps1
# no change     /Users/akshadapradhan/Documents/anaconda3/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /Users/akshadapradhan/Documents/anaconda3/etc/profile.d/conda.csh
# no change     /Users/akshadapradhan/.bash_profile
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
ls
# Out:
# Dockerfile           configuration_files/ requirements.txt
# LICENSE.txt          cossmo/              setup.py
# README.md            cossmo_tests/        ts1/
# Untitled.ipynb       environment.yml
# bin/                 environment_gpu.yml

# %%
conda install -c conda-forge tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/akshadapradhan/Documents/anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.0      |       he49afe7_0         936 KB  conda-forge
#     absl-py-1.0.0              |     pyhd8ed1ab_0          95 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     blinker-1.4                |             py_1          13 KB  conda-forge
#     ca-certificates-2021.10.8  |       h033912b_0         139 KB  conda-forge
#     cachetools-4.2.4           |     pyhd8ed1ab_0          12 KB  conda-forge
#     certifi-2021.10.8          |   py39h6e9494a_2         144 KB  conda-forge
#     conda-4.12.0               |   py39h6e9494a_0         1.0 MB  conda-forge
#     dbus-1.13.6                |       ha13b53f_2         544 KB  conda-forge
#     expat-2.4.4                |       he49afe7_0         145 KB  conda-forge
#     gast-0.3.3                 |             py_0          12 KB  conda-forge
#     gettext-0.19.8.1           |    h7937167_1005         3.3 MB  conda-forge
#     glib-2.68.4                |       he49afe7_0         429 KB  conda-forge
#     glib-tools-2.68.4          |       he49afe7_0          81 KB  conda-forge
#     google-auth-1.21.3         |             py_0          56 KB  conda-forge
#     google-auth-oauthlib-0.4.6 |     pyhd8ed1ab_0          19 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpc-cpp-1.37.1            |       h541e7bd_0         2.8 MB  conda-forge
#     grpcio-1.37.1              |   py39hb974310_0         2.0 MB  conda-forge
#     h5py-2.10.0                |nompi_py39h1bb8402_106         941 KB  conda-forge
#     icu-68.2                   |       he49afe7_0        12.7 MB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     libclang-11.1.0            |default_he082bbe_1        14.4 MB  conda-forge
#     libglib-2.68.4             |       hd556434_0         2.8 MB  conda-forge
#     libpq-13.3                 |       hea3049e_0         2.7 MB  conda-forge
#     libprotobuf-3.15.8         |       hcf210ce_1         2.2 MB  conda-forge
#     libxml2-2.9.12             |       h93ec3fd_0         685 KB  conda-forge
#     libxslt-1.1.33             |       h5739fc3_2         488 KB  conda-forge
#     lxml-4.8.0                 |   py39h63b48b0_2         1.3 MB  conda-forge
#     markdown-3.3.6             |     pyhd8ed1ab_0          67 KB  conda-forge
#     mysql-common-8.0.25        |       h694c41f_0         1.5 MB  conda-forge
#     mysql-libs-8.0.25          |       h54f5a68_0         1.7 MB  conda-forge
#     nspr-4.32                  |       hcd9eead_1         247 KB  conda-forge
#     nss-3.69                   |       h31e2bf1_1         2.0 MB  conda-forge
#     oauthlib-3.2.0             |     pyhd8ed1ab_0          90 KB  conda-forge
#     openssl-1.1.1n             |       h6c3fc93_0         1.9 MB  conda-forge
#     opt_einsum-3.3.0           |     pyhd8ed1ab_1          53 KB  conda-forge
#     pcre-8.45                  |       he49afe7_0         220 KB  conda-forge
#     protobuf-3.15.8            |   py39h9fcab8e_0         317 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pyqt-5.12.3                |   py39h6e9494a_8          22 KB  conda-forge
#     pyqt-impl-5.12.3           |   py39he44290a_8         4.7 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py39h15fb055_8         275 KB  conda-forge
#     pyqtchart-5.12             |   py39he44290a_8         213 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py39he44290a_8         140 KB  conda-forge
#     python-flatbuffers-1.12    |     pyhd8ed1ab_1          19 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     qt-5.12.9                  |       h126340a_4        87.8 MB  conda-forge
#     re2-2021.04.01             |       he49afe7_0         190 KB  conda-forge
#     requests-oauthlib-1.3.1    |     pyhd8ed1ab_0          22 KB  conda-forge
#     rsa-4.8                    |     pyhd8ed1ab_0          31 KB  conda-forge
#     tensorboard-2.4.1          |     pyhd8ed1ab_1         8.8 MB  conda-forge
#     tensorboard-plugin-wit-1.8.1|     pyhd8ed1ab_0         668 KB  conda-forge
#     tensorflow-2.4.1           |   py39h6e9494a_0          25 KB  conda-forge
#     tensorflow-base-2.4.1      |   py39h9e0eb93_0       116.3 MB  conda-forge
#     tensorflow-estimator-2.4.0 |     pyh9656e83_0         289 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       277.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/osx-64::abseil-cpp-20210324.0-he49afe7_0
#   absl-py            conda-forge/noarch::absl-py-1.0.0-pyhd8ed1ab_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   astunparse         conda-forge/noarch::astunparse-1.6.3-pyhd8ed1ab_0
#   blinker            conda-forge/noarch::blinker-1.4-py_1
#   cachetools         conda-forge/noarch::cachetools-4.2.4-pyhd8ed1ab_0
#   dbus               conda-forge/osx-64::dbus-1.13.6-ha13b53f_2
#   expat              conda-forge/osx-64::expat-2.4.4-he49afe7_0
#   gast               conda-forge/noarch::gast-0.3.3-py_0
#   gettext            conda-forge/osx-64::gettext-0.19.8.1-h7937167_1005
#   glib               conda-forge/osx-64::glib-2.68.4-he49afe7_0
#   glib-tools         conda-forge/osx-64::glib-tools-2.68.4-he49afe7_0
#   google-auth        conda-forge/noarch::google-auth-1.21.3-py_0
#   google-auth-oauth~ conda-forge/noarch::google-auth-oauthlib-0.4.6-pyhd8ed1ab_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpc-cpp           conda-forge/osx-64::grpc-cpp-1.37.1-h541e7bd_0
#   grpcio             conda-forge/osx-64::grpcio-1.37.1-py39hb974310_0
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   libclang           conda-forge/osx-64::libclang-11.1.0-default_he082bbe_1
#   libglib            conda-forge/osx-64::libglib-2.68.4-hd556434_0
#   libpq              conda-forge/osx-64::libpq-13.3-hea3049e_0
#   libprotobuf        conda-forge/osx-64::libprotobuf-3.15.8-hcf210ce_1
#   markdown           conda-forge/noarch::markdown-3.3.6-pyhd8ed1ab_0
#   mysql-common       conda-forge/osx-64::mysql-common-8.0.25-h694c41f_0
#   mysql-libs         conda-forge/osx-64::mysql-libs-8.0.25-h54f5a68_0
#   nspr               conda-forge/osx-64::nspr-4.32-hcd9eead_1
#   nss                conda-forge/osx-64::nss-3.69-h31e2bf1_1
#   oauthlib           conda-forge/noarch::oauthlib-3.2.0-pyhd8ed1ab_0
#   opt_einsum         conda-forge/noarch::opt_einsum-3.3.0-pyhd8ed1ab_1
#   pcre               conda-forge/osx-64::pcre-8.45-he49afe7_0
#   protobuf           conda-forge/osx-64::protobuf-3.15.8-py39h9fcab8e_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pyqt-impl          conda-forge/osx-64::pyqt-impl-5.12.3-py39he44290a_8
#   pyqt5-sip          conda-forge/osx-64::pyqt5-sip-4.19.18-py39h15fb055_8
#   pyqtchart          conda-forge/osx-64::pyqtchart-5.12-py39he44290a_8
#   pyqtwebengine      conda-forge/osx-64::pyqtwebengine-5.12.1-py39he44290a_8
#   python-flatbuffers conda-forge/noarch::python-flatbuffers-1.12-pyhd8ed1ab_1
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#   re2                conda-forge/osx-64::re2-2021.04.01-he49afe7_0
#   requests-oauthlib  conda-forge/noarch::requests-oauthlib-1.3.1-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.8-pyhd8ed1ab_0
#   tensorboard        conda-forge/noarch::tensorboard-2.4.1-pyhd8ed1ab_1
#   tensorboard-plugi~ conda-forge/noarch::tensorboard-plugin-wit-1.8.1-pyhd8ed1ab_0
#   tensorflow         conda-forge/osx-64::tensorflow-2.4.1-py39h6e9494a_0
#   tensorflow-base    conda-forge/osx-64::tensorflow-base-2.4.1-py39h9e0eb93_0
#   tensorflow-estima~ conda-forge/noarch::tensorflow-estimator-2.4.0-pyh9656e83_0
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#
# The following packages will be UPDATED:
#
#   icu                        pkgs/main::icu-58.2-h0a44026_3 --> conda-forge::icu-68.2-he49afe7_0
#   lxml                 pkgs/main::lxml-4.6.3-py39h26b266a_0 --> conda-forge::lxml-4.8.0-py39h63b48b0_2
#   pyqt                 pkgs/main::pyqt-5.9.2-py39h23ab428_6 --> conda-forge::pyqt-5.12.3-py39h6e9494a_8
#   qt                         pkgs/main::qt-5.9.7-h468cd18_1 --> conda-forge::qt-5.12.9-h126340a_4
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.3.29-~ --> conda-forge::ca-certificates-2021.10.8-h033912b_0
#   certifi            pkgs/main::certifi-2021.10.8-py39hecd~ --> conda-forge::certifi-2021.10.8-py39h6e9494a_2
#   conda              pkgs/main::conda-4.12.0-py39hecd8cb5_0 --> conda-forge::conda-4.12.0-py39h6e9494a_0
#   h5py                 pkgs/main::h5py-3.2.1-py39h90fc2a2_0 --> conda-forge::h5py-2.10.0-nompi_py39h1bb8402_106
#   libxml2              pkgs/main::libxml2-2.9.12-hcdb78fc_0 --> conda-forge::libxml2-2.9.12-h93ec3fd_0
#   libxslt              pkgs/main::libxslt-1.1.34-h83b36ba_0 --> conda-forge::libxslt-1.1.33-h5739fc3_2
#   openssl              pkgs/main::openssl-1.1.1n-hca72f7f_0 --> conda-forge::openssl-1.1.1n-h6c3fc93_0
#
#
#
# Downloading and Extracting Packages
# qt-5.12.9            | 87.8 MB   | ##################################### | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ##################################### | 100%
# pcre-8.45            | 220 KB    | ##################################### | 100%
# oauthlib-3.2.0       | 90 KB     | ##################################### | 100%
# pyqt-impl-5.12.3     | 4.7 MB    | ##################################### | 100%
# tensorboard-2.4.1    | 8.8 MB    | ##################################### | 100%
# pyqtchart-5.12       | 213 KB    | ##################################### | 100%
# pyqt-5.12.3          | 22 KB     | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# libpq-13.3           | 2.7 MB    | ##################################### | 100%
# tensorflow-base-2.4. | 116.3 MB  | ##################################### | 100%
# openssl-1.1.1n       | 1.9 MB    | ##################################### | 100%
# libxml2-2.9.12       | 685 KB    | ##################################### | 100%
# pyasn1-0.4.8         | 53 KB     | ##################################### | 100%
# re2-2021.04.01       | 190 KB    | ##################################### | 100%
# libxslt-1.1.33       | 488 KB    | ##################################### | 100%
# nspr-4.32            | 247 KB    | ##################################### | 100%
# abseil-cpp-20210324. | 936 KB    | ##################################### | 100%
# grpcio-1.37.1        | 2.0 MB    | ##################################### | 100%
# tensorboard-plugin-w | 668 KB    | ##################################### | 100%
# astunparse-1.6.3     | 15 KB     | ##################################### | 100%
# lxml-4.8.0           | 1.3 MB    | ##################################### | 100%
# dbus-1.13.6          | 544 KB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# requests-oauthlib-1. | 22 KB     | ##################################### | 100%
# icu-68.2             | 12.7 MB   | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# opt_einsum-3.3.0     | 53 KB     | ##################################### | 100%
# tensorflow-estimator | 289 KB    | ##################################### | 100%
# absl-py-1.0.0        | 95 KB     | ##################################### | 100%
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# python-flatbuffers-1 | 19 KB     | ##################################### | 100%
# pyqtwebengine-5.12.1 | 140 KB    | ##################################### | 100%
# h5py-2.10.0          | 941 KB    | ##################################### | 100%
# protobuf-3.15.8      | 317 KB    | ##################################### | 100%
# rsa-4.8              | 31 KB     | ##################################### | 100%
# tensorflow-2.4.1     | 25 KB     | ##################################### | 100%
# libclang-11.1.0      | 14.4 MB   | ##################################### | 100%
# nss-3.69             | 2.0 MB    | ##################################### | 100%
# mysql-libs-8.0.25    | 1.7 MB    | ##################################### | 100%
# certifi-2021.10.8    | 144 KB    | ##################################### | 100%
# libprotobuf-3.15.8   | 2.2 MB    | ##################################### | 100%
# conda-4.12.0         | 1.0 MB    | ##################################### | 100%
# libglib-2.68.4       | 2.8 MB    | ##################################### | 100%
# gast-0.3.3           | 12 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# google-auth-oauthlib | 19 KB     | ##################################### | 100%
# expat-2.4.4          | 145 KB    | ##################################### | 100%
# grpc-cpp-1.37.1      | 2.8 MB    | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# blinker-1.4          | 13 KB     | ##################################### | 100%
# mysql-common-8.0.25  | 1.5 MB    | ##################################### | 100%
# glib-2.68.4          | 429 KB    | ##################################### | 100%
# cachetools-4.2.4     | 12 KB     | ##################################### | 100%
# pyqt5-sip-4.19.18    | 275 KB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.3 MB    | ##################################### | 100%
# glib-tools-2.68.4    | 81 KB     | ##################################### | 100%
# google-auth-1.21.3   | 56 KB     | ##################################### | 100%
# markdown-3.3.6       | 67 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import cossmo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/nk/00bqbmts04b61zn48rj3_0740000gn/T/ipykernel_54822/3237762376.py in <module>
# ----> 1 import cossmo
#
# ~/Downloads/COSSMO-master/cossmo/__init__.py in <module>
#      16         return tf.unstack(tf.shape(tensor))[dim]
#      17
# ---> 18 from . import scoring_network
#
# ~/Downloads/COSSMO-master/cossmo/scoring_network.py in <module>
#       3 from .dna_encoder import dna_encoder
#       4 from .constants import INTRON_LENGTH_DISTRIBUTION
# ----> 5 import tensorflow.contrib.layers as layers
#       6
#       7 MIN_FLOAT = np.finfo(np.float32).min
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
conda install tensorflow==1.13.2
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - tensorflow==1.13.2
#
# Current channels:
#
#   - https://conda.anaconda.org/bioconda/osx-64
#   - https://conda.anaconda.org/bioconda/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
